# %%
API_KEY = "AIzaSyAQ1BKkI_81Oucf2HPKHo8Kmye6FxkKPZM"

# %%
# !pip install google-api-python-client

# %%
from googleapiclient.discovery import build

# %%
# Create youtube resource object
myYoutube = build('youtube',
                  'v3',
                  developerKey=API_KEY)

# %%
# Retrieve youtube civdeo comments
video_response = myYoutube.commentThreads().list(
    part='snippet, replies',
    videoId='hBpepnlqaTo',
).execute()

# %%
count = 0
# Iterate youtube comments
for item in video_response["items"]:
    count+=1
    print("Comment-", count, ": ")
    comment = item["snippet"]["topLevelComment"]["snippet"]["textDisplay"]
    print(comment)
# Out:
# Comment- 1 :
# Hello guys, please do a short survey for me! I need you guys help :) <br><a href="https://forms.gle/GUgVCNkEoAfBMZJW9">https://forms.gle/GUgVCNkEoAfBMZJW9</a>
# Comment- 2 :
# Tat will be nice if moontoon give kunfu panda skin to baxia master ogkwa😂😂
# Comment- 3 :
# Always op game play general bro
# Comment- 4 :
# Baxia and florin combo is op
# Comment- 5 :
# Late upload
# Comment- 6 :
# tbh im not that desperate to use baxia
# Comment- 7 :
# I was playing close attention on this match on your stream general but to be honest all though he is OP but I&#39;ve never seen a team in high rank use baxia jg without a support hero. What im trying to say is baxia is not that a problem. But the reasoning here is baxia can&#39;t handle all that damage without him getting heal from somewhere elsee so I&#39;d floryn gets to be the Goat here. Respectfully bro
# Comment- 8 :
# Baxia is so good, specially this season that healers are so OP!
# Comment- 9 :
# Wow amazinnn🎉
# ...

# %%
# Extract userid, userimage, comment, and replies on comment
count = 0
# Iterate youtube comments
for item in video_response["items"]:
    count+=1
    print("Comment-", count, ": ")
    comment = item["snippet"]["topLevelComment"]["snippet"]["textDisplay"]
    user = item["snippet"]["topLevelComment"]["snippet"]["authorDisplayName"]
    user_image = item["snippet"]["topLevelComment"]["snippet"]["authorProfileImageUrl"]
    print("User: ", user)
    print("User Image: ", user_image)
    print("Comment: ", comment)
    print("\n")
    print("Replies: ")
    try:
        replies = item["replies"]["comments"]
        for reply in replies:
            reply = reply["snippet"]["textDisplay"]
            print(reply)
    except:
        print("No replies")
    print("\n\n")
# Out:
# Comment- 1 :
# User:  Gosu General TV
# User Image:  https://yt3.ggpht.com/ytc/APkrFKZbBLqwj8Er6LrAMcHwa5NXZqhyMKfnU4a9vmMYwA=s48-c-k-c0x00ffffff-no-rj
# Comment:  Hello guys, please do a short survey for me! I need you guys help :) <br><a href="https://forms.gle/GUgVCNkEoAfBMZJW9">https://forms.gle/GUgVCNkEoAfBMZJW9</a>
#
#
# Replies:
# idol general please help me😥
# Long time no G4❤😢
# Yo gosu what are the builds from hayabusa
# take love general ❤
# done❤
#
#
#
# Comment- 2 :
# User:  Fan of MLBB 🔥
# User Image:  https://yt3.ggpht.com/TQV8gaP0bEsGgz0ymkeZHOiSJMBxi2B1HjNnAB4klUx8lm53syu65Z3dQU4_B6_QNDJf1OrTiMc=s48-c-k-c0x00ffffff-no-rj
# Comment:  Tat will be nice if moontoon give kunfu panda skin to baxia master ogkwa😂😂
#
#
# Replies:
# No replies
#
#
#
# Comment- 3 :
# User:  Aitor Debbarma
# User Image:  https://yt3.ggpht.com/ytc/APkrFKayZGE_hKph2OWOeqIVdTJHIPoH5U8L2-PYh1kWJGZ9kYVfuaBZnv4_3v8RFlZG=s48-c-k-c0x00ffffff-no-rj
# Comment:  Always op game play general bro
#
#
# ...
